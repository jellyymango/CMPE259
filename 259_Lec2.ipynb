# %% [markdown]
# <a href="https://colab.research.google.com/github/jellyymango/CMPE259/blob/main/259_Lec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date

print(date.today())
# Out:
# 2026-08-25
